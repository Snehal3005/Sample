# %% [markdown]
# # Assignment No.3

# %% [markdown]
# 1. What are the benefits of including roles in the programmes?
#
#     Since this assignment is related to function, I assume the question is “What are the benefits of including functions
#     in the programmes?”
#
#     Functions allow us to use the same code again and again (reusability). Functions make our program easy to read,
#     understand and update.
#
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
#     The code in function run when function is called, not when it is specified.
#
#
#
# 3. What statement causes a feature to be created?
#
#     Since this assignment is related to function, I assume the question is “. What statement causes a function to be
#     created?”
#
#     The def statement creates a function.
#
#
#
# 4. What is the distinction between a function and a call to a function?
#
#     Function is nothing but a function definition where, set of code is written to achieve a particular result.
#     It just sits idle until it is called.
#
#     Function call is transfer of a control from main program to the start of function execution and it returns some value.
#
#
#
# 5. In a Python application, how many global scopes are there? How many local scopes are there?
#
#     There is only one global scope. Variables in this scope are accessible to all the code.
#
#     There can be any number of local scopes. Local scope is limited to that particular function. Variables in this scope are accessible locally only.
#
#
#
# 6. When a function call returns, what happens to variables in the local scope?
#
#     When a function call returns, variables in the local scope become undefined.
#
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
#     Return value is the value, which is the result of function execution. Yes, it possible to have a return value in
#     an expression.
#
#
#
# 8. What is the return value of a call to a function that does not have a return statement?
#
#     None.
#
#
#
# 9. How do you make a function variable refer to the global variable?
#
#     Global statement allow us to not only access the global variable but also modify them from inside the function.
#
#
#
# 10. What data form does None belong to?
#
#     Data form is NoneType.
#
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
#     This import sentence imports a module named “areallyourpetsnamederic”.
#
#
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
#     Function is called like this:
#
#     spam.bacon()
#
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
#     We can use try clause.
#
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
#     The code that cause an error goes in the try clause.
#
#     The code that executes if an error happens goes in the except clause.
