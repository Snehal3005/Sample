# %% [markdown]
# 1. Write a Python program to find sum of elements in list?

# %%
def sum1(numbers):
    sum_elements = 0
    for i in numbers:
        sum_elements += i
    return sum_elements

#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1

print(f'Sum of elements in {numbers} is {sum1(numbers)}')
# Out:
# Enter number of elements in list::4
# Enter a number::44
# Enter a number::33
# Enter a number::22
# Enter a number::11
# Sum of elements in [44, 33, 22, 11] is 110

# %% [markdown]
# 2. Write a Python program to Multiply all numbers in the list?

# %%
def multiply(numbers):
    mul_elements = 1
    for i in numbers:
        mul_elements *= i
    return mul_elements

#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1

print(f'Multiplication of elements in {numbers} is {multiply(numbers)}')
# Out:
# Enter number of elements in list::4
# Enter a number::1
# Enter a number::12
# Enter a number::23
# Enter a number::34
# Multiplication of elements in [1, 12, 23, 34] is 9384

# %% [markdown]
# 3. Write a Python program to find smallest number in a list?

# %%
def find_smallest_num(numbers):
    min1 = numbers[0]
    
    for i in range(1,len(numbers)):
        if numbers[i] < min1:
            min1 = numbers[i]
    return min1

#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    

print('Smallest number of the list is ',find_smallest_num(numbers))
# Out:
# Enter number of elements in list::4
# Enter a number::12
# Enter a number::98
# Enter a number::34
# Enter a number::76
# Smallest number of the list is  12

# %% [markdown]
# 4. Write a Python program to find largest number in a list?

# %%
def find_largest_num(numbers):
    max1 = numbers[0]
    
    for i in range(1,len(numbers)):
        if numbers[i] > max1:
            max1 = numbers[i]
    return max1

#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    
print('The largest number of the list is ',find_largest_num(numbers))
# Out:
# Enter number of elements in list::4
# Enter a number::76
# Enter a number::23
# Enter a number::98
# Enter a number::78
# The largest number of the list is  98

# %% [markdown]
# 5. Write a Python program to find second largest number in a list?

# %%
#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    

numbers.sort()
print('Second largest number in a list is ',numbers[len(numbers)-2])
# Out:
# Enter number of elements in list::4
# Enter a number::12
# Enter a number::98
# Enter a number::56
# Enter a number::87
# Second largest number in a list is  87

# %% [markdown]
# 6. Write a Python program to find N largest elements from a list?

# %%
#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    

numbers.sort()
N = int(input('Enter the Nth number::'))

print(f'{N}th largest number in a list is {numbers[len(numbers)-N]}')
# Out:
# Enter number of elements in list::4
# Enter a number::12
# Enter a number::34
# Enter a number::76
# Enter a number::21
# Enter the Nth number::3
# 3th largest number in a list is 21

# %% [markdown]
# 7. Write a Python program to print even numbers in a list?

# %%
def check_even(numbers):
    return [i for i in numbers if i%2 == 0 ]
    
#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    

print('Even elements in a list are ',check_even(numbers))
# Out:
# Enter number of elements in list::4
# Enter a number::1
# Enter a number::2
# Enter a number::3
# Enter a number::4
# Even elements in a list are  [2, 4]

# %% [markdown]
# 8. Write a Python program to print odd numbers in a List?

# %%
def check_odd(numbers):
    return [i for i in numbers if i%2 != 0 ]
    
#input list elements
numbers = []

n = int(input('Enter number of elements in list::'))

while n > 0:
    numbers.append(int(input('Enter a number::')))
    n -= 1    

print('Odd elements in a list are ',check_odd(numbers))
# Out:
# Enter number of elements in list::4
# Enter a number::1
# Enter a number::2
# Enter a number::3
# Enter a number::4
# Odd elements in a list are  [1, 3]

# %% [markdown]
# 9. Write a Python program to Remove empty List from List?

# %%
l = [1,2,3,[],['a','b'],[],(4,5,6,7)]
print('List before removing empty list from list',l)
for i in l:
    if type(i) == list and len(i) == 0:
        l.remove(i)

print('List after removing empty list from list',l)
# Out:
# List before removing empty list from list [1, 2, 3, [], ['a', 'b'], [], (4, 5, 6, 7)]
# List after removing empty list from list [1, 2, 3, ['a', 'b'], (4, 5, 6, 7)]

# %% [markdown]
# 10. Write a Python program to Cloning or Copying a list?

# %%
l = [1, 2, 3, ['a', 'b'], (4, 5, 6, 7)]
print('Original list is ', l)

l1 = []
for i in l:
    l1.append(i)
    
print('New list after copying is ', l1)
# Out:
# Original list is  [1, 2, 3, ['a', 'b'], (4, 5, 6, 7)]
# New list after copying is  [1, 2, 3, ['a', 'b'], (4, 5, 6, 7)]

# %% [markdown]
# 11. Write a Python program to Count occurrences of an element in a list?

# %%
l = [1, 2, 3, ['a', 'b'], (4, 5, 6, 7),1,2,1]
print('Original list is ', l)

e = int(input('Enter the element to find the occurences ::'))
count = 0

for i in l:
    if e == i:
        count += 1
        
print(f'{e} has occured {count} times')
# Out:
# Original list is  [1, 2, 3, ['a', 'b'], (4, 5, 6, 7), 1, 2, 1]
# Enter the element to find the occurences ::1
# 1 has occured 3 times
